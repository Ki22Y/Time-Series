# %%
import pandas as pd
data=pd.read_csv('raw_sales.csv')

# %%
data.head()
# Out:
#               datesold  postcode   price propertyType  bedrooms
# 0  2007-02-07 00:00:00      2607  525000        house         4
# 1  2007-02-27 00:00:00      2906  290000        house         3
# 2  2007-03-07 00:00:00      2905  328000        house         3
# 3  2007-03-09 00:00:00      2905  380000        house         4
# 4  2007-03-21 00:00:00      2906  310000        house         3

# %%
data.tail()
# Out:
#                   datesold  postcode   price propertyType  bedrooms
# 29575  2019-07-25 00:00:00      2900  500000         unit         3
# 29576  2019-07-25 00:00:00      2612  560000         unit         2
# 29577  2019-07-26 00:00:00      2912  464950         unit         2
# 29578  2019-07-26 00:00:00      2601  589000         unit         2
# 29579  2019-07-26 00:00:00      2612  775000         unit         2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29580 entries, 0 to 29579
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datesold      29580 non-null  object
#  1   postcode      29580 non-null  int64
#  2   price         29580 non-null  int64
#  3   propertyType  29580 non-null  object
#  4   bedrooms      29580 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 1.1+ MB

# %%
newdate=data.loc[(data['datesold'] >= '2018-01-01 00:00:00')&(data['datesold'] < '2018-12-31 00:00:00')]
newdate
# Out:
#                   datesold  postcode    price propertyType  bedrooms
# 20666  2018-01-03 00:00:00      2600  1200000        house         4
# 20667  2018-01-05 00:00:00      2611   850000        house         4
# 20668  2018-01-05 00:00:00      2617   980000        house         5
# 20669  2018-01-08 00:00:00      2600   330000        house         2
# 20670  2018-01-08 00:00:00      2615   485000        house         3
# ...                    ...       ...      ...          ...       ...
# 29212  2018-12-21 00:00:00      2615   323000         unit         2
# 29213  2018-12-21 00:00:00      2604   475000         unit         2
# 29214  2018-12-21 00:00:00      2914   495000         unit         3
# 29215  2018-12-21 00:00:00      2602   535000         unit         3
# 29216  2018-12-21 00:00:00      2612   580000         unit         2
#
# [3858 rows x 5 columns]

# %%
data.drop('postcode',axis=1)
# Out:
#                   datesold   price propertyType  bedrooms
# 0      2007-02-07 00:00:00  525000        house         4
# 1      2007-02-27 00:00:00  290000        house         3
# 2      2007-03-07 00:00:00  328000        house         3
# 3      2007-03-09 00:00:00  380000        house         4
# 4      2007-03-21 00:00:00  310000        house         3
# ...                    ...     ...          ...       ...
# 29575  2019-07-25 00:00:00  500000         unit         3
# 29576  2019-07-25 00:00:00  560000         unit         2
# 29577  2019-07-26 00:00:00  464950         unit         2
# 29578  2019-07-26 00:00:00  589000         unit         2
# 29579  2019-07-26 00:00:00  775000         unit         2
#
# [29580 rows x 4 columns]

# %%
data['datesold'] = pd.to_datetime(data['datesold'], format='%Y/%m/%d')
data
# Out:
#         datesold  postcode   price propertyType  bedrooms
# 0     2007-02-07      2607  525000        house         4
# 1     2007-02-27      2906  290000        house         3
# 2     2007-03-07      2905  328000        house         3
# 3     2007-03-09      2905  380000        house         4
# 4     2007-03-21      2906  310000        house         3
# ...          ...       ...     ...          ...       ...
# 29575 2019-07-25      2900  500000         unit         3
# 29576 2019-07-25      2612  560000         unit         2
# 29577 2019-07-26      2912  464950         unit         2
# 29578 2019-07-26      2601  589000         unit         2
# 29579 2019-07-26      2612  775000         unit         2
#
# [29580 rows x 5 columns]

# %%
# Out:
# 29580

# %%
newdate=data.loc[(data['datesold'] >= '2010-01-01 00:00:00')&(data['datesold'] < '2015-12-31 00:00:00')]
newdate
# Out:
#         datesold  postcode    price propertyType  bedrooms
# 1957  2010-01-04      2615   435000        house         3
# 1958  2010-01-05      2904   712000        house         4
# 1959  2010-01-06      2617   435000        house         4
# 1960  2010-01-06      2606  1350000        house         5
# 1961  2010-01-07      2905   612500        house         4
# ...          ...       ...      ...          ...       ...
# 26612 2015-12-23      2603   415000         unit         2
# 26613 2015-12-23      2612   438000         unit         2
# 26614 2015-12-23      2612   450000         unit         2
# 26615 2015-12-23      2605   515000         unit         2
# 26616 2015-12-24      2900   365000         unit         2
#
# [13676 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(dt)

# %%
dt=data.groupby(data['datesold'].dt.year)['price'].mean()
dt
# Out:
# datesold
# 2007    522377.210884
# 2008    493814.162754
# 2009    496092.032959
# 2010    559564.810289
# 2011    566715.110227
# 2012    552501.369214
# 2013    553416.296838
# 2014    592653.761439
# 2015    626101.342654
# 2016    635185.311668
# 2017    671880.551420
# 2018    660701.042768
# 2019    634184.218773
# Name: price, dtype: float64

# %%
dt1=data.groupby(data['datesold'].dt.year)['price'].count()
dt1
# Out:
# datesold
# 2007     147
# 2008     639
# 2009    1426
# 2010    1555
# 2011    1633
# 2012    1858
# 2013    2119
# 2014    2863
# 2015    3648
# 2016    3908
# 2017    4541
# 2018    3858
# 2019    1385
# Name: price, dtype: int64

# %%
plt.plot(dt1)
